# %%
# 1. Distribution of ratings for AZ restaurants
sns.histplot(df_reviews_restaurants_az['stars_y'], bins=5, kde=True)
plt.title("Distribution of Restaurant Ratings in AZ")
plt.xlabel("Stars")
plt.ylabel("Frequency")
plt.show()

# 2. Review length analysis
df_reviews_restaurants_az['review_length'] = df_reviews_restaurants_az['text'].apply(lambda x: len(str(x).split()))
sns.boxplot(x=df_reviews_restaurants_az['stars_y'], y=df_reviews_restaurants_az['review_length'])
plt.title("Review Length by Rating in AZ")
plt.xlabel("Star Rating")
plt.ylabel("Word Count")
plt.show()

# 3. Sentiment Analysis
df_reviews_restaurants_az['sentiment'] = df_reviews_restaurants_az['text'].apply(lambda x: TextBlob(str(x)).sentiment.polarity)
sns.histplot(df_reviews_restaurants_az['sentiment'], bins=30, kde=True)
plt.title("Sentiment Score Distribution for AZ Restaurants")
plt.xlabel("Sentiment Score")
plt.ylabel("Frequency")
plt.show()

# 4. Word Cloud for Common Words in Reviews
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(" ".join(df_reviews_restaurants_az['text'].dropna()))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Common Words in AZ Restaurant Reviews")
plt.show()

# 5. Geospatial Analysis: Heatmap of Restaurant Ratings
m = folium.Map(location=[az_restaurants_df['latitude'].mean(), az_restaurants_df['longitude'].mean()], zoom_start=10)
heat_data = [[row['latitude'], row['longitude'], row['stars']] for index, row in az_restaurants_df.iterrows()]
HeatMap(heat_data).add_to(m)
m.save("az_restaurant_heatmap.html")
print("Heatmap saved as az_restaurant_heatmap.html")

#6. Distribution of Stars
plt.figure(figsize=(8, 5))
df_reviews_restaurants_az['stars_y'].value_counts().sort_index().plot(kind='bar', color='orange', alpha=0.7)
plt.xlabel('Star Rating')
plt.ylabel('Number of Reviews')
plt.title('Distribution of Star Ratings')
plt.xticks(rotation=0)
plt.show()
